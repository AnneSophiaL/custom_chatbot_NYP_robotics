# %%
# This code is working approximately ! The data imported is not used but the chatbot can answer queries.

# %%
# import openai
# import json

# # Authentification à l'API
# openai.api_key = "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"

# # Charger les données d'entraînement
# with open("FIFA23.json", "r") as f:
#     training_data = json.load(f)

# # Définir la fonction de traitement
# def generate_response(input_text):
#     # Recherchez les exemples de données d'entraînement pertinents
#     for example in training_data:
#         if input_text.lower() in example["input"].lower():
#             return example["output"]
    
#     # Si aucun exemple ne correspond, utilisez GPT-3 pour générer une réponse
#     response = openai.Completion.create(
#         engine="text-davinci-002",
#         prompt=input_text,
#         max_tokens=1024,
#         n=1,
#         stop=None,
#         temperature=0.5,
#     )
    
#     return response.choices[0].text.strip()

# # Exemple d'utilisation de la fonction de traitement
# while True:
#     user_input = input("User: ")
#     response = generate_response(user_input)
#     print("Chatbot:", response)

# %%
# this code works, but does not use data from "test_NYP_robotics copy.txt" (uses data of New York Institute of Technology)
import openai

# Authentification à l'API
openai.api_key = "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"

# Charger les données d'entraînement à partir d'un fichier texte
with open("test_NYP_robotics copy.txt", "r") as f:
    text_data = f.readlines()

# Transformer les données en un format similaire au JSON attendu
training_data = []
for i in range(len(text_data) - 1):
    input_text = text_data[i].strip()
    output_text = text_data[i+1].strip()
    training_data.append({"input": input_text, "output": output_text})

# Définir la fonction de traitement
def generate_response(input_text):
    # Recherchez les exemples de données d'entraînement pertinents
    for example in training_data:
        if input_text.lower() in example["input"].lower():
            return example["output"]
    
    # Si aucun exemple ne correspond, utilisez GPT-3 pour générer une réponse
    response = openai.Completion.create(
        model="text-davinci-002",
        prompt=input_text,
        max_tokens=1024,
        n=1,
        stop=None,
        temperature=0.5,
    )
    
    return response.choices[0].text.strip()

# Exemple d'utilisation de la fonction de traitement
while True:
    user_input = input("User: ")
    response = generate_response(user_input)
    print("Chatbot:", response)
# Out:
# Chatbot: New York Institute of Technology provides over 100 degree and certificate programs.
# Chatbot:
# Chatbot: offered by the college
#
# 1. Accounting
# 2. Business Administration
# 3. Economics
# 4. Entrepreneurship
# 5. Finance
# 6. Human Resources Management
# 7. International Business
# 8. Management
# 9. Marketing
# 10. Project Management
# 11. Public Administration
# 12. Real Estate
# 13. Sports Management
# 14. Supply Chain Management
# 15. Tourism Management
# 16. Event Management
# 17. Hospitality Management
# 18. Information Systems Management
# 19. Non-Profit Management
# 20. Retail Management
# Chatbot:
# Chatbot:
# Chatbot:
# Chatbot:
# Chatbot:
# Chatbot:
# Chatbot:
# Chatbot:
# Chatbot:
# Chatbot:
# Chatbot:
# Chatbot:
# Chatbot:
# Chatbot:
# Chatbot:
# Chatbot:
# Chatbot:
# Chatbot:
# Chatbot:
# Chatbot:
# Chatbot: The file is called "training data."
# ...

# %%
# this code works, but does not use data from "test_NYP_robotics copy.txt" (uses data of New York Institute of Technology)
import openai

# Authentification à l'API
openai.api_key = "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"

# Charger les données d'entraînement à partir d'un fichier texte
with open("test_NYP_robotics copy 2.txt", "r") as f:
    text_data = f.readlines()

# Transformer les données en un format similaire au JSON attendu
training_data = []
for i in range(len(text_data) - 1):
    input_text = text_data[i].strip()
    output_text = text_data[i+1].strip()
    training_data.append({"input": input_text, "output": output_text})

# Définir la fonction de traitement
def generate_response(input_text):
    # Recherchez les exemples de données d'entraînement pertinents
    for example in training_data:
        if input_text.lower() in example["input"].lower():
            return example["output"]
    
    # Si aucun exemple ne correspond, utilisez GPT-3 pour générer une réponse
    response = openai.Completion.create(
        model="text-davinci-003",
        prompt=input_text,
        max_tokens=1024,
        n=1,
        stop=None,
        temperature=0.5,
    )
    
    return response.choices[0].text.strip()

# Exemple d'utilisation de la fonction de traitement
while True:
    user_input = input("User: ")
    response = generate_response(user_input)
    print("Chatbot:", response)
# Out:
# Chatbot: The courses provided by the Institute of Education Sciences (IES) include:
#
# 1. Educational Leadership
# 2. Educational Technology
# 3. Educational Psychology
# 4. Curriculum and Instruction
# 5. Special Education
# 6. School Counseling
# 7. Research Methods
# 8. School Improvement
# 9. Educational Policy
# 10. Assessment and Evaluation
# 11. Instructional Design
# 12. Literacy and Reading
# 13. Mathematics Education
# 14. Science Education
# 15. Social Studies Education
# 16. English Language Arts Education
# 17. Arts Education
# 18. Health Education
# 19. Physical Education
# 20. Early Childhood Education
# ...
